# %% [markdown]
# <a href="https://colab.research.google.com/github/jeongyeon8425/colab/blob/main/%EA%B1%B0%EB%B6%81%EC%9D%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 거북이

# %%
#!pip3 install ColabTurtle
import ColabTurtle.Turtle as turtle
import random
print(turtle.DEFAULT_WINDOW_SIZE)
turtle.initializeTurtle()

while True :
  turtle.left(random.randint(0,360))
  turtle.forward(random.randint(100,200))
  if 800 <= turtle.getx() or turtle.getx() <= 0 or \
  500 <= turtle.gety() or turtle.gety() <= 0 :
    turtle.goto(400,250)
# Out:
# (800, 500)
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...
